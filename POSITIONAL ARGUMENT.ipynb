# %%
#Function - are block of code which can be executed repetively
#There are two types of function
      #Built in function -these function pre-defined and stored in python library (print(), input()
      #user defined function - defined by the programmer as per the requirement.
#to create user defined function
# -def
# -function name
# -parameter(optional)
# -return(optional)
#we need to call the function to execute the statement defined inside a function
#argument and parameter
def display(name):
    print(name)

display("Priya" -- > priya -- argument (it's a actual value)
display(name) --> name -- parameter(its a variable that will hold the argument value)

# %%
def sum(*num):
    total = 0
    for n in num:
        total += n
    return total

r = sum(23,34,45,57,60,30,20,12,30,17)
print("Sum",r)
# Out:
# Sum 328
