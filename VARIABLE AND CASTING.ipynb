# %%
#This is a variable
x = 5
y = "IRET"
print(x)
print(y)
# Out:
# 5
# IRET

# %%
x = 8       # x is of type int
x = "IRET"  # X is now of type str
print(x)
# Out:
# IRET

# %%
#This is Casting
x = str(3)   # x will be '3'
x = int(3)   # x will be 3
x = float(3) # x will be 3.0
print(x),(x),(x)
# Out:
# 3.0
# (None, 3.0, 3.0)

# %%
#This is a type function
x = 9
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Single or Double Quotes?
x = "IRET"
# is the same as 
x = 'IRET'
print(x)
# Out:
# IRET
