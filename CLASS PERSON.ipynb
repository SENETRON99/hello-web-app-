# %%
class Person:
    def accepts(self):
        self.name = input("Enter a name")
        self.age = int(input("Enter your age"))
        self.city =input("Enter your city name")
        self.salary= float(input("Enter your salary"))

    def display(self):
            print("Details: \n")
            print(f"Name : {self.name}")

p = Person()
p.accepts()
p.display()
# Out:
# Enter a name ABIDOSHEKA
# Enter your age 20
# Enter your city name IKEJA
# Enter your salary 500000
# Details:
#
# Name : ABIDOSHEKA

# %%
class Person:
    def accepts(self):
        self.name = input("Enter a name")
        self.age = int(input("Enter your age"))
        self.city = input("Enter your city name")
        
    def income(self):
        self.salary= float(input("Enter your salary"))

    def display(self):
        print("Details: \n")
        print(f"Name : {self.name}")

p = Person()
p.accepts()
p.income()
p.display()
# Out:
# Enter a name TEMITOPE
# Enter your age 21
# Enter your city name EKO MAINLAND
# Enter your salary 100000
# Details:
#
# Name : TEMITOPE
