# %%
var=10
print(var)
# Out:
# 10

# %%
num1=10
num2=20
print(num1+num2)
# Out:
# 30

# %%
num1 = int(input ("Enter First number: "))
num2 = int(input ("Enter Second number: "))
sum = num1 + num2 
print("the sum of two numbers is", sum)
# Out:
# Enter First number:  57
# Enter Second number:  56
# the sum of two numbers is 113

# %%
a = 10 
b = 3.14
c = 2+5j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
