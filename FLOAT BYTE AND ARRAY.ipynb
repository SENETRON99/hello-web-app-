# %%
var=10
print(var)
# Out:
# 10

# %%
var=23
print(var)
# Out:
# 23

# %%
X=45
print(X)
# Out:
# 45

# %%
num1=10
num2=20
print(num1+num2)
# Out:
# 30

# %%
num1 = input("Enter First number")
num2 = input("Enter Second number")
print(num1+num2)
# Out:
# Enter First number 67
# Enter Second number 45
# 6745

# %%
num1 = input("Enter First number")
num2 = input("Enter Second number")
sum = num1 + num2
print("the sum of the two number is", sum)
# Out:
# Enter First number 44
# Enter Second number 56
# the sum of the two number is 4456

# %%
num1 =int(input("Enter First number"))
num2 =int(input("Enter Second number"))
sum = num1 + num2
print("the sum of two numbers is", sum)
# Out:
# Enter First number 44
# Enter Second number 56
# the sum of two numbers is 100

# %%
num1 =int(input("Enter First number"))
num2 =int(input("Enter Second number"))
num3 =int(input("Enter Third number"))
sum = num1 + num2 + num3
print("the sum of three numbers is", sum)
# Out:
# Enter First number 35
# Enter Second number 67
# Enter Third number 85
# the sum of three numbers is 187

# %%
num1 =int(input("Enter First number"))
num2 =int(input("Enter Second number"))
num3 =int(input("Enter Third number"))
num4 =int(input("Enter Fourth number"))
sum = num1 + num2 + num3 + num4
print("the sum of the four numbers is", sum)
# Out:
# Enter First number 25
# Enter Second number 56
# Enter Third number 74
# Enter Fourth number 108
# the sum of the four numbers is 263

# %%
val1 = input("Enter First number")
val2 = input("Enter Second number")
val1 = val2
val2 = val1
print(val1, val2)
# Out:
# Enter First number 65
# Enter Second number 37
# 37 37

# %%
val1 = input("Enter First number")
val2 = input("Enter Second number")
temp = val2
val2 = val1
val1 = temp
print(val1, val2)
# Out:
# Enter First number 40
# Enter Second number 68
# 68 40

# %%
a = 10
b = 3.14
c = 2 + 3j
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 10
# 3.14
# (2+3j)
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x = 2    # int
y = 3.8  # float
z = 4j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 2.0
# 3
# (2+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
#from W3 Python tutorial
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = "Hello, World"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 20.5
print(type(x))
# Out:
# <class 'float'>

# %%
x = 1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x = ["apple", "banana", "cherry"]
print(type(x))
# Out:
# <class 'list'>

# %%
x = ("apple", "banana", "cherry")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = range(6)
print(type(x))
# Out:
# <class 'range'>

# %%
x = {"name" : "John", "age" : 36}
print(type(x))
# Out:
# <class 'dict'>

# %%
x = {"apple", "banana", "cherry"}
print(type(x))
# Out:
# <class 'set'>

# %%
x = frozenset({"apple", "banana", "cherry"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x = True
x = False
print(type(x))
# Out:
# <class 'bool'>

# %%
x = b"Hello"
print(type(x))
# Out:
# <class 'bytes'>

# %%
x = bytearray(7)
print(type(x))
# Out:
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>
