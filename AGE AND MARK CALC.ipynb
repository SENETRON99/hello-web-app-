# %%
age = 20
if age >= 18:
    print("you are an adult")
print("you are a kid")
# Out:
# you are an adult
# you are a kid

# %%
age = 20
if age>= 18:
    print("You are an adult, and you can vote")
else:
    print("You are a kid, and you cannot vote")
# Out:
# You are an adult, and you can vote

# %%
age = 16
if age >= 18:
     print("You are an adult, and you can vote")
     print("True block will not be executed")
else:
  print("You are a kid, and you cannot vote")
  print("You are in else block")
print("This is outside if else")
# Out:
# You are a kid, and you cannot vote
# You are in else block
# This is outside if else

# %%
marks = 76
if marks >= 90:
    print("Distintion")
elif marks >= 75 and marks < 90:
    print("Upper Credit")
elif marks >= 60 and marks < 75:
    print("Lower Credit")
else:
    print("Pass")
# Out:
# Upper Credit

# %%
age = 24
citizen = True
if age > 18:
    if citizen:
        print("You are eligible to vote")
    else:
        print("You are not eligible to vote")
else:
   print("You are not adult")
# Out:
# You are eligible to vote

# %%
temp = 30
if temp > 35:
    print("it's hot")
elif temp > 25:
    print("it's warm")
else:
    print("it's cool")
# Out:
# it's warm
