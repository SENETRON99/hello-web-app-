# %%
def function_name(paramters):
    #code block
    return result

# %%
def greet(msg):
    name = "Priya"
    return f"{msg} {name}"

# %%
def student(name, age):
    print(f"{name} is {age} years old")

student("Priya", 36)
# Out:
# Priya is 36 years old

# %%
#funtion definition
def message():
    print("I am a function")
#function calling
message()
# Out:
# I am a function

# %%
#write a program to create a function which perform a task of adding two numbers and displaying the result
def add(num1,num2):
  num3 = num1+num2
  print("Result", num3)

add(8,9)
# Out:
# Result 17

# %%
#write a program to create a function which add two numbers
def add(num1,num2):
    num3 = num1+num2
    print("Result", num3)

add(8,6)
# Out:
# Result 14

# %%
#write a program to create a funtion which substract two number
def substract(num2,num1):
    num3 = num2-num1
    print("Result", num3)
#passing the argument(actual values)
substract(20,8)
# Out:
# Result 12

# %%
#write a program with a function which accepts name,course and display them
def info (name,course):
    print("Name :",name)
    print("Course :",course)
    
info("Shuchi","Python")
# Out:
# Name : Shuchi
# Course : Python

# %%
#write a program with a function which accepts name,course and display them
def myinfo(name,course):
    print("Name :",name)
    print("Course :",course)

myinfo("Priya","Java")
# Out:
# Name : Priya
# Course : Java

# %%
def emp_info(emp_id,emp_name,emp_dept):
    print("Employee ID",emp_id)
    print("Employee Name",emp_name)
    print("Employee Dept",emp_dept)

emp_info(201,"Iret","Elect_elect")
# Out:
# Employee ID 201
# Employee Name Iret
# Employee Dept Elect_elect

# %%
#keyword argument
def emp_info(emp_id,emp_name,emp_dept):
    print("Employee ID",emp_id)
    print("Employee Name",emp_name)
    print("Employee Dept",emp_dept)
emp_info(emp_name="SHUCHI",emp_dept="IT",emp_id="201")
# Out:
# Employee ID 201
# Employee Name SHUCHI
# Employee Dept IT

# %%
#function with input
def accept():
    num1 = input("Enter First Number")
    num2 = input("Enter Second Number")
    if(num1>num2):
        print(num1,"is greater than ",num2)
    else:
        print(num2," is greater than ",num1)

accept()
# Out:
# Enter First Number 4
# Enter Second Number 9
# 9  is greater than  4

# %%
#checking and input function
def check(num1,num2):
    if(num1>num2):
        print(num1," is greater than ",num2)
    else:    
        print(num2," is greater than ",num1)
        
num1 = int(input("Enter First Number"))
num2 = int(input("Enter Second Number"))

check(num1,num2)
# Out:
# Enter First Number 4
# Enter Second Number 9
# 9  is greater than  4

# %%
def personnal_details():
    name = input("Enter student name")
    course = input("Enter student course")
    print("My name is",name)
    print("My course is",course)

personnal_details()
# Out:
# Enter student name Damilola
# Enter student course Accountancy
# My name is Damilola
# My course is Accountancy

# %%
#default argument
def emp_info(emp_id,emp_name,emp_dept,mgr_id="NA"):
    print("Employee ID",emp_id)
    print("Employee Name",emp_name)
    print("Employee Dept",emp_dept)
    print("Employee Manager",mgr_id)

emp_info(101,"Adeolu","Python")

emp_info(102,"Olamide","Java Script",203)
# Out:
# Employee ID 101
# Employee Name Adeolu
# Employee Dept Python
# Employee Manager NA
# Employee ID 102
# Employee Name Olamide
# Employee Dept Java Script
# Employee Manager 203

# %%
#write a program to accept student details(name,course,fees,discount) make discount as a default argument
#Write a program to create a function to calculate the square of a given number
#write a program to create a function to check eligibility for a vote,age should be above 18
