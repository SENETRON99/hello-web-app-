# %%
def function_name(paramters):
    #code block
    return result

# %%
def greet(msg):
    name = "Priya"
    return f"{msg} {name}"

# %%
def student(name, age):
    print(f"{name} is {age} years old")

student("Priya", 36)
# Out:
# Priya is 36 years old
