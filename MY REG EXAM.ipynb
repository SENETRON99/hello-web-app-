# %%
seats =0
while seats<3:
    seats+=1
    print("Bus Full")
# Out:
# Bus Full
# Bus Full
# Bus Full

# %%
price=500
discount=50
final_price=price-discount*2
print("final_price")
# Out:
# final_price

# %%
mydict = {"name": "Shuchi", "age": 53, "address": "India"}
emptydict = {}
print(mydict)
print(mydict["name"])
print(mydict["age"])
print(mydict["address"])
# Out:
# {'name': 'Shuchi', 'age': 53, 'address': 'India'}
# Shuchi
# 53
# India

# %%
mydict ={"name": "Shuchi", "age":57, "address": "India"}
emptydict= {}
print(mydict["name"]) #First way to access dictionary elements
print(mydict.get("name")) #Second way to access dictionary elements
# Out:
# Shuchi
# Shuchi

# %%
mydict = {"name": "IRETOMIWA", "age": 30, "address": "Nigeria"}
emptydict = {}
print(mydict["name"]) #First way to access dictionary elements
print(mydict.get("name")) #Second way to access dictionary elements
print(mydict["age"])
print(mydict.get("age"))
print(mydict["address"])
print(mydict.get("address"))
# Out:
# IRETOMIWA
# IRETOMIWA
# 30
# 30
# Nigeria
# Nigeria

# %%
mydict = {"name": "Shuchi", "age":53, "address": "India"}
emptydict = {}
print(mydict["age"])
print(mydict.get("names", "Not Found"))
# Out:
# 53
# Not Found

# %%
mydict = {"name": "Shuchi", "age":53, "address": "India"}
emptydict = {}
print(mydict["age"])
mydict["name"] = "Doreen"
print(mydict.get("name", "Not Found"))
# Out:
# 53
# Doreen

# %%
mydict ={"name": "Shuchi", "age":53, "address": "India"}
emptydict = {}
print(mydict["age"])
mydict["name"] = "Doreen"
del mydict["address"]
print(mydict)
# Out:
# 53
# {'name': 'Doreen', 'age': 53}

# %%
#Dictionary function
#length
#string
#type

# %%
#print the length of my dictionary
mydict = {"name": "Shuchi", "age":53, "address": "India"}
emptydict ={}
print(len(mydict))
# Out:
# 3

# %%
#print the length of an empty dictionary
mydict = {"name": "Shuchi", "age":53, "address": "India"}
emptydict = {}
print(len(emptydict))
# Out:
# 0

# %%
#Nested Dictionary
mydict = {"person": {"name": "Doreen", "age":35}, "Citizenship": "Australian", "qualification": "graduate"}
print(len(mydict))
# Out:
# 3

# %%
#Nested Dictionary
mydict = {"person": {"name": "Doreen", "age":35}, "Citizenship": "Australian", "qualification": "graduate"}
emptydict = {}
print(mydict["person"])
# Out:
# {'name': 'Doreen', 'age': 35}

# %%
#Nested Dictionary
mydict ={"person": {"name": "Doreen", "age":45}, "Citizenship": "Australian", "qualification": "graduate"}
emptydict ={}
print(mydict["person"]["name"])
print(mydict["person"]["age"])
# Out:
# Doreen
# 45

# %%
#String function
mydict = {"person": {"name": "Doreen", "age":48}, "Citizenship": "Australian", "qualification": "graduate"}
emptydict ={}
print(str(mydict))
# Out:
# {'person': {'name': 'Doreen', 'age': 48}, 'Citizenship': 'Australian', 'qualification': 'graduate'}

# %%
#Type function
mydict = {"person": {"name": "Doreen", "age":50}, "Citizenship": "Australian", "qualification": "graduate"}
emptydict = {}
print(str(mydict))
print(type(mydict))
print(type(str(mydict)))
# Out:
# {'person': {'name': 'Doreen', 'age': 50}, 'Citizenship': 'Australian', 'qualification': 'graduate'}
# <class 'dict'>
# <class 'str'>
